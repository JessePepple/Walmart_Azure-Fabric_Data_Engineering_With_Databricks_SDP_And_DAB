# %%
param = [
    {"table_val" : "dim_products"},
    {"table_val" : "dim_customers"},
    {"table_val" : "dim_orders"},
    {"table_val" : "dim_employees"},
    {"table_val" : "dim_stores"},
    {"table_val" : "fact_order_items"},
    {"table_val" : "walmart_obt"}
]

# %%
dbutils.jobs.taskValues.set(key="param", value=param)
