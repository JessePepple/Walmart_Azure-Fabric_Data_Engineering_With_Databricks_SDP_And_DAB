# %%
dbutils.widgets.text("table_val", " ")
table_val = dbutils.widgets.get("table_val")

# %%
df = spark.read.table(f"walmart_catalog.gold.{table_val}")

df.write.format("delta").mode("append").option("mergeSchema", "true").save(f"abfss://gold@walmartlakejess.dfs.core.windows.net/{table_val}_curated")
df.display()
